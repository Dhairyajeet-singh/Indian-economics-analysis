# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **DATASET.CSV IS CREATED BY THE HELP ON 'ONCERUN.ipynb' file**

# %% [markdown]
# # **IF THERE IS ALREADY A FILE NAME DATASET.CSV DON'T RUN 'ONCERUN.ipynb'**

# %%
df1 = pd.read_csv('dataset.csv')

# %%
df1
# Out:
#     Unnamed: 0  year         GDP Per_Capita Annual_percent_geowth  \
# 0            0  2022  $3,416.65B     $2,411                 7.24%
# 1            1  2021  $3,150.31B     $2,238                 9.05%
# 2            2  2020  $2,671.60B     $1,913                -5.83%
# 3            3  2019  $2,835.61B     $2,050                 3.87%
# 4            4  2018  $2,702.93B     $1,974                 6.45%
# ..         ...   ...         ...        ...                   ...
# 58          58  1964     $56.48B       $115                 7.45%
# 59          59  1963     $48.42B       $101                 5.99%
# 60          60  1962     $42.16B        $90                 2.93%
# 61          61  1961     $39.23B        $86                 3.72%
# 62          62  1960     $37.03B        $83                 0.00%
#
#     Unnamed: 0.1  year.1 billions_of_us percent_of_GDP  Unnamed: 0.2  ...  \
# 0              0    2022       $456.06B         13.35%             0  ...
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0  year         GDP Per_Capita Annual_percent_geowth  \
# 0           0  2022  $3,416.65B     $2,411                 7.24%
# 1           1  2021  $3,150.31B     $2,238                 9.05%
# 2           2  2020  $2,671.60B     $1,913                -5.83%
# 3           3  2019  $2,835.61B     $2,050                 3.87%
# 4           4  2018  $2,702.93B     $1,974                 6.45%
#
#    Unnamed: 0.1  year.1 billions_of_us percent_of_GDP  Unnamed: 0.2  ...  \
# 0             0    2022       $456.06B         13.35%             0  ...
# 1             1    2021       $455.91B         14.47%             1  ...
# 2             2    2020       $377.35B         14.12%             2  ...
# 3             3    2019       $381.55B         13.46%             3  ...
# 4             4    2018       $402.24B         14.88%             4  ...
#
#    Per_Capita.2 Annual_percent_geowth.2 Unnamed: 0.7  year.7  \
# 0        $2,390                   7.20%            0    2022
# ...

# %%
df1.size
# Out:
# 2457

# %%
df1.shape
# Out:
# (63, 39)

# %%
df1.head()
# Out:
#    Unnamed: 0  year         GDP Per_Capita Annual_percent_geowth  \
# 0           0  2022  $3,416.65B     $2,411                 7.24%
# 1           1  2021  $3,150.31B     $2,238                 9.05%
# 2           2  2020  $2,671.60B     $1,913                -5.83%
# 3           3  2019  $2,835.61B     $2,050                 3.87%
# 4           4  2018  $2,702.93B     $1,974                 6.45%
#
#    Unnamed: 0.1  year.1 billions_of_us percent_of_GDP  Unnamed: 0.2  ...  \
# 0             0    2022       $456.06B         13.35%             0  ...
# 1             1    2021       $455.91B         14.47%             1  ...
# 2             2    2020       $377.35B         14.12%             2  ...
# 3             3    2019       $381.55B         13.46%             3  ...
# 4             4    2018       $402.24B         14.88%             4  ...
#
#    Per_Capita.2 Annual_percent_geowth.2 Unnamed: 0.7  year.7  \
# 0        $2,390                   7.20%            0    2022
# ...

# %%
df1.tail()
# Out:
#     Unnamed: 0  year      GDP Per_Capita Annual_percent_geowth  Unnamed: 0.1  \
# 58          58  1964  $56.48B       $115                 7.45%            58
# 59          59  1963  $48.42B       $101                 5.99%            59
# 60          60  1962  $42.16B        $90                 2.93%            60
# 61          61  1961  $39.23B        $86                 3.72%            61
# 62          62  1960  $37.03B        $83                 0.00%            62
#
#     year.1 billions_of_us percent_of_GDP  Unnamed: 0.2  ...  Per_Capita.2  \
# 58    1964         $8.39B         14.85%            58  ...          $110
# 59    1963         $7.63B         15.75%            59  ...          $100
# 60    1962         $6.69B         15.86%            60  ...           $90
# 61    1961         $6.02B         15.35%            61  ...            $0
# 62    1960         $5.46B         14.75%            62  ...            $0
#
#    Annual_percent_geowth.2 Unnamed: 0.7  year.7  \
# ...

# %%
for column in df1.columns:
    print(column)
# Out:
# Unnamed: 0
# year
# GDP
# Per_Capita
# Annual_percent_geowth
# Unnamed: 0.1
# year.1
# billions_of_us
# percent_of_GDP
# Unnamed: 0.2
# year.2
# GDP_growth
# Annual_Change
# Unnamed: 0.3
# year.3
# GDP_Per_Capita
# Annual_Change.1
# Unnamed: 0.4
# year.4
# Per_Capita.1
# GNI
# Annual_Change.2
# Unnamed: 0.5
# year.5
# GNI_Per_Capita
# Annual_percent_geowth.1
# Unnamed: 0.6
# year.6
# GNP
# Per_Capita.2
# Annual_percent_geowth.2
# Unnamed: 0.7
# year.7
# Government_Debt_as_percent_of_GDP
# Annual_percent_geowth.3
# Unnamed: 0.8
# year.8
# Inflation_Rate
# Annual_percent_geowth.4

# %%
df1.drop(['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.2','Unnamed: 0.3','Unnamed: 0.4','Unnamed: 0.5','Unnamed: 0.6', 'Unnamed: 0.7', 'Unnamed: 0.8'],axis=1, inplace=True)

# %%
df1.drop(['year.1','year.2','year.3','year.4','year.5','year.6','year.7','year.8'], axis=1, inplace=True)

# %%
df1.shape
# Out:
# (63, 22)

# %%
df1.head()
# Out:
#    year         GDP Per_Capita Annual_percent_geowth billions_of_us  \
# 0  2022  $3,416.65B     $2,411                 7.24%       $456.06B
# 1  2021  $3,150.31B     $2,238                 9.05%       $455.91B
# 2  2020  $2,671.60B     $1,913                -5.83%       $377.35B
# 3  2019  $2,835.61B     $2,050                 3.87%       $381.55B
# 4  2018  $2,702.93B     $1,974                 6.45%       $402.24B
#
#   percent_of_GDP GDP_growth Annual_Change GDP_Per_Capita Annual_Change.1  ...  \
# 0         13.35%      7.24%        -1.81%         $2,411           7.72%  ...
# 1         14.47%      9.05%        14.88%         $2,238          16.98%  ...
# 2         14.12%     -5.83%        -9.70%         $1,913          -6.68%  ...
# 3         13.46%      3.87%        -2.58%         $2,050           3.84%  ...
# 4         14.88%      6.45%        -0.34%         $1,974           0.84%  ...
#
#   Annual_Change.2 GNI_Per_Capita Annual_percent_geowth.1         GNP  \
# ...

# %%
for column in df1.columns:
    print(column)
# Out:
# year
# GDP
# Per_Capita
# Annual_percent_geowth
# billions_of_us
# percent_of_GDP
# GDP_growth
# Annual_Change
# GDP_Per_Capita
# Annual_Change.1
# Per_Capita.1
# GNI
# Annual_Change.2
# GNI_Per_Capita
# Annual_percent_geowth.1
# GNP
# Per_Capita.2
# Annual_percent_geowth.2
# Government_Debt_as_percent_of_GDP
# Annual_percent_geowth.3
# Inflation_Rate
# Annual_percent_geowth.4

# %%
df1.drop(['Annual_Change.1','Annual_Change.2','Annual_percent_geowth.1','Annual_percent_geowth.2','Per_Capita.1','Per_Capita.2',"Annual_percent_geowth.3",'Annual_percent_geowth.4'],axis=1,inplace=True)

# %%
df1
# Out:
#     year         GDP Per_Capita Annual_percent_geowth billions_of_us  \
# 0   2022  $3,416.65B     $2,411                 7.24%       $456.06B
# 1   2021  $3,150.31B     $2,238                 9.05%       $455.91B
# 2   2020  $2,671.60B     $1,913                -5.83%       $377.35B
# 3   2019  $2,835.61B     $2,050                 3.87%       $381.55B
# 4   2018  $2,702.93B     $1,974                 6.45%       $402.24B
# ..   ...         ...        ...                   ...            ...
# 58  1964     $56.48B       $115                 7.45%         $8.39B
# 59  1963     $48.42B       $101                 5.99%         $7.63B
# 60  1962     $42.16B        $90                 2.93%         $6.69B
# 61  1961     $39.23B        $86                 3.72%         $6.02B
# 62  1960     $37.03B        $83                 0.00%         $5.46B
#
#    percent_of_GDP GDP_growth Annual_Change GDP_Per_Capita     GNI  \
# 0          13.35%      7.24%        -1.81%         $2,411  $2,390
# ...

# %%
for column in df1.columns:
    print(column)
# Out:
# year
# GDP
# Per_Capita
# Annual_percent_geowth
# billions_of_us
# percent_of_GDP
# GDP_growth
# Annual_Change
# GDP_Per_Capita
# GNI
# GNI_Per_Capita
# GNP
# Government_Debt_as_percent_of_GDP
# Inflation_Rate

# %%
df1.describe()
# Out:
#               year
# count    63.000000
# mean   1991.000000
# std      18.330303
# min    1960.000000
# 25%    1975.500000
# 50%    1991.000000
# 75%    2006.500000
# max    2022.000000

# %%
df1
# Out:
#     year         GDP Per_Capita Annual_percent_geowth billions_of_us  \
# 0   2022  $3,416.65B     $2,411                 7.24%       $456.06B
# 1   2021  $3,150.31B     $2,238                 9.05%       $455.91B
# 2   2020  $2,671.60B     $1,913                -5.83%       $377.35B
# 3   2019  $2,835.61B     $2,050                 3.87%       $381.55B
# 4   2018  $2,702.93B     $1,974                 6.45%       $402.24B
# ..   ...         ...        ...                   ...            ...
# 58  1964     $56.48B       $115                 7.45%         $8.39B
# 59  1963     $48.42B       $101                 5.99%         $7.63B
# 60  1962     $42.16B        $90                 2.93%         $6.69B
# 61  1961     $39.23B        $86                 3.72%         $6.02B
# 62  1960     $37.03B        $83                 0.00%         $5.46B
#
#    percent_of_GDP GDP_growth Annual_Change GDP_Per_Capita     GNI  \
# 0          13.35%      7.24%        -1.81%         $2,411  $2,390
# ...

# %%
df1.describe(include='object')
# Out:
#                GDP Per_Capita Annual_percent_geowth billions_of_us  \
# count           63         63                    63             63
# unique          63         62                    61             63
# top     $3,416.65B        $90                 7.86%       $456.06B
# freq             1          2                     2              1
#
#        percent_of_GDP GDP_growth Annual_Change GDP_Per_Capita   GNI  \
# count              63         63            63             63    63
# unique             61         61            61             62    47
# top            15.02%      7.86%         3.72%            $90  $110
# freq                2          2             2              2     6
#
#        GNI_Per_Capita GNP Government_Debt_as_percent_of_GDP Inflation_Rate
# count              63  63                                63             63
# unique             47  62                                30             63
# ...

# %%
df1.rename(columns={'Annual_percent_geowth':'Annual_percent_growth'},inplace=True)

# %%
df1.drop(['Per_Capita'],axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['year', 'GDP', 'Annual_percent_growth', 'billions_of_us',
#        'percent_of_GDP', 'GDP_growth', 'Annual_Change', 'GDP_Per_Capita',
#        'GNI', 'GNI_Per_Capita', 'GNP', 'Government_Debt_as_percent_of_GDP',
#        'Inflation_Rate'],
#       dtype='object')

# %%
df1
# Out:
#     year         GDP Annual_percent_growth billions_of_us percent_of_GDP  \
# 0   2022  $3,416.65B                 7.24%       $456.06B         13.35%
# 1   2021  $3,150.31B                 9.05%       $455.91B         14.47%
# 2   2020  $2,671.60B                -5.83%       $377.35B         14.12%
# 3   2019  $2,835.61B                 3.87%       $381.55B         13.46%
# 4   2018  $2,702.93B                 6.45%       $402.24B         14.88%
# ..   ...         ...                   ...            ...            ...
# 58  1964     $56.48B                 7.45%         $8.39B         14.85%
# 59  1963     $48.42B                 5.99%         $7.63B         15.75%
# 60  1962     $42.16B                 2.93%         $6.69B         15.86%
# 61  1961     $39.23B                 3.72%         $6.02B         15.35%
# 62  1960     $37.03B                 0.00%         $5.46B         14.75%
#
#    GDP_growth Annual_Change GDP_Per_Capita     GNI GNI_Per_Capita         GNP  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   year                               63 non-null     int64
#  1   GDP                                63 non-null     object
#  2   Annual_percent_growth              63 non-null     object
#  3   billions_of_us                     63 non-null     object
#  4   percent_of_GDP                     63 non-null     object
#  5   GDP_growth                         63 non-null     object
#  6   Annual_Change                      63 non-null     object
#  7   GDP_Per_Capita                     63 non-null     object
#  8   GNI                                63 non-null     object
#  9   GNI_Per_Capita                     63 non-null     object
#  10  GNP                                63 non-null     object
# ...

# %%
df1.drop(['Government_Debt_as_percent_of_GDP'], axis=1, inplace=True)

# %%
df1
# Out:
#     year         GDP Annual_percent_growth billions_of_us percent_of_GDP  \
# 0   2022  $3,416.65B                 7.24%       $456.06B         13.35%
# 1   2021  $3,150.31B                 9.05%       $455.91B         14.47%
# 2   2020  $2,671.60B                -5.83%       $377.35B         14.12%
# 3   2019  $2,835.61B                 3.87%       $381.55B         13.46%
# 4   2018  $2,702.93B                 6.45%       $402.24B         14.88%
# ..   ...         ...                   ...            ...            ...
# 58  1964     $56.48B                 7.45%         $8.39B         14.85%
# 59  1963     $48.42B                 5.99%         $7.63B         15.75%
# 60  1962     $42.16B                 2.93%         $6.69B         15.86%
# 61  1961     $39.23B                 3.72%         $6.02B         15.35%
# 62  1960     $37.03B                 0.00%         $5.46B         14.75%
#
#    GDP_growth Annual_Change GDP_Per_Capita     GNI GNI_Per_Capita         GNP  \
# ...

# %%
df1.head()
# Out:
#    year         GDP Annual_percent_growth billions_of_us percent_of_GDP  \
# 0  2022  $3,416.65B                 7.24%       $456.06B         13.35%
# 1  2021  $3,150.31B                 9.05%       $455.91B         14.47%
# 2  2020  $2,671.60B                -5.83%       $377.35B         14.12%
# 3  2019  $2,835.61B                 3.87%       $381.55B         13.46%
# 4  2018  $2,702.93B                 6.45%       $402.24B         14.88%
#
#   GDP_growth Annual_Change GDP_Per_Capita     GNI GNI_Per_Capita         GNP  \
# 0      7.24%        -1.81%         $2,411  $2,390         $2,390  $3,385.77B
# 1      9.05%        14.88%         $2,238  $2,150         $2,150  $3,019.86B
# 2     -5.83%        -9.70%         $1,913  $1,900         $1,900  $2,659.60B
# 3      3.87%        -2.58%         $2,050  $2,080         $2,080  $2,878.54B
# 4      6.45%        -0.34%         $1,974  $1,980         $1,980  $2,713.33B
#
#   Inflation_Rate
# 0          6.70%
# 1          5.13%
# ...

# %%
df1.tail()
# Out:
#     year      GDP Annual_percent_growth billions_of_us percent_of_GDP  \
# 58  1964  $56.48B                 7.45%         $8.39B         14.85%
# 59  1963  $48.42B                 5.99%         $7.63B         15.75%
# 60  1962  $42.16B                 2.93%         $6.69B         15.86%
# 61  1961  $39.23B                 3.72%         $6.02B         15.35%
# 62  1960  $37.03B                 0.00%         $5.46B         14.75%
#
#    GDP_growth Annual_Change GDP_Per_Capita   GNI GNI_Per_Capita      GNP  \
# 58      7.45%         1.46%           $115  $110           $110  $52.54B
# 59      5.99%         3.06%           $101  $100           $100  $45.73B
# 60      2.93%        -0.79%            $90   $90            $90  $41.17B
# 61      3.72%         3.72%            $86    $0             $0       $B
# 62      0.00%         3.72%            $83    $0             $0       $B
#
#    Inflation_Rate
# 58         13.36%
# 59          2.95%
# 60          3.63%
# 61          1.70%
# ...

# %%
df1.shape
# Out:
# (63, 12)

# %%
df1.drop(['year'],axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['GDP', 'Annual_percent_growth', 'billions_of_us', 'percent_of_GDP',
#        'GDP_growth', 'Annual_Change', 'GDP_Per_Capita', 'GNI',
#        'GNI_Per_Capita', 'GNP', 'Inflation_Rate'],
#       dtype='object')

# %% [markdown]
# **columns explained**
#
# 1) Here GDP is gross domestic product
# 2) Annual percent growth is the percentage by which the economy grows or declines
# 3) billion of us represents debt over india in us dollars
# 4) percent of gdp defies how much percentage of total gdp is debt
# 5) gdp growth defies the growth of gdp
# 6) annual change defies the annual change in gdp
# 7) GDP per capita is GDP per person or economic ouput of a country per person
# 8) GNI defies total income earned by a country's buisnesses and people no matter where it is earned (gross national income)
# 9) GNI per capita is GNI per person
# 10) GNP, Gross national product defies he total value of all finished goods and services produced by a country's citizens in a given financial year, irrespective of their location
# 11) inflation rate the rate by which currency depriciates

# %%
df1.describe()
# Out:
#                GDP Annual_percent_growth billions_of_us percent_of_GDP  \
# count           63                    63             63             63
# unique          63                    61             63             61
# top     $3,416.65B                 7.86%       $456.06B         15.02%
# freq             1                     2              1              2
#
#        GDP_growth Annual_Change GDP_Per_Capita   GNI GNI_Per_Capita GNP  \
# count          63            63             63    63             63  63
# unique         61            61             62    47             47  62
# top         7.86%         3.72%            $90  $110           $110  $B
# freq            2             2              2     6              6   2
#
#        Inflation_Rate
# count              63
# unique             63
# top             6.70%
# freq                1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GDP                    63 non-null     object
#  1   Annual_percent_growth  63 non-null     object
#  2   billions_of_us         63 non-null     object
#  3   percent_of_GDP         63 non-null     object
#  4   GDP_growth             63 non-null     object
#  5   Annual_Change          63 non-null     object
#  6   GDP_Per_Capita         63 non-null     object
#  7   GNI                    63 non-null     object
#  8   GNI_Per_Capita         63 non-null     object
#  9   GNP                    63 non-null     object
#  10  Inflation_Rate         63 non-null     object
# dtypes: object(11)
# memory usage: 5.5+ KB

# %%
df1.isnull().sum() #checking for nulls
# Out:
# GDP                      0
# Annual_percent_growth    0
# billions_of_us           0
# percent_of_GDP           0
# GDP_growth               0
# Annual_Change            0
# GDP_Per_Capita           0
# GNI                      0
# GNI_Per_Capita           0
# GNP                      0
# Inflation_Rate           0
# dtype: int64

# %%
#no null values

# %%
df1.dtypes
# Out:
# GDP                      object
# Annual_percent_growth    object
# billions_of_us           object
# percent_of_GDP           object
# GDP_growth               object
# Annual_Change            object
# GDP_Per_Capita           object
# GNI                      object
# GNI_Per_Capita           object
# GNP                      object
# Inflation_Rate           object
# dtype: object

# %%
#we need to convert all the object into integers for further processing and model building

# %%
def convert_to_numeric(val):
    try:
        if isinstance(val, str):
            val = val.replace('$', '').replace(',', '').strip()  # Remove $ and commas
            if 'B' in val:
                return float(val.replace('B', '')) * 1e9  # Convert billions to numeric
            elif 'M' in val:
                return float(val.replace('M', '')) * 1e6  # Convert millions to numeric
            elif '%' in val:
                return float(val.replace('%',''))
        return float(val)  # Try converting to float
    except ValueError:
        return None

# %%
for col in df1.columns:
    df1[col] = df1[col].apply(convert_to_numeric)

# %%
df1
# Out:
#              GDP  Annual_percent_growth  billions_of_us  percent_of_GDP  \
# 0   3.416650e+12                   7.24    4.560600e+11           13.35
# 1   3.150310e+12                   9.05    4.559100e+11           14.47
# 2   2.671600e+12                  -5.83    3.773500e+11           14.12
# 3   2.835610e+12                   3.87    3.815500e+11           13.46
# 4   2.702930e+12                   6.45    4.022400e+11           14.88
# ..           ...                    ...             ...             ...
# 58  5.648000e+10                   7.45    8.390000e+09           14.85
# 59  4.842000e+10                   5.99    7.630000e+09           15.75
# 60  4.216000e+10                   2.93    6.690000e+09           15.86
# 61  3.923000e+10                   3.72    6.020000e+09           15.35
# 62  3.703000e+10                   0.00    5.460000e+09           14.75
#
#     GDP_growth  Annual_Change  GDP_Per_Capita     GNI  GNI_Per_Capita  \
# ...

# %%
df1.head()
# Out:
#             GDP  Annual_percent_growth  billions_of_us  percent_of_GDP  \
# 0  3.416650e+12                   7.24    4.560600e+11           13.35
# 1  3.150310e+12                   9.05    4.559100e+11           14.47
# 2  2.671600e+12                  -5.83    3.773500e+11           14.12
# 3  2.835610e+12                   3.87    3.815500e+11           13.46
# 4  2.702930e+12                   6.45    4.022400e+11           14.88
#
#    GDP_growth  Annual_Change  GDP_Per_Capita     GNI  GNI_Per_Capita  \
# 0        7.24          -1.81          2411.0  2390.0          2390.0
# 1        9.05          14.88          2238.0  2150.0          2150.0
# 2       -5.83          -9.70          1913.0  1900.0          1900.0
# 3        3.87          -2.58          2050.0  2080.0          2080.0
# 4        6.45          -0.34          1974.0  1980.0          1980.0
#
#             GNP  Inflation_Rate
# 0  3.385770e+12            6.70
# 1  3.019860e+12            5.13
# ...

# %%
#now we have all the data in integer form we can create graphs and digitally expres the data

# %%
df1.hist(figsize=(15,10), bins=20)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(df1)
plt.show()

# %%
sns.boxplot(df1['GNP'])
plt.show()

# %%
df1.head()
# Out:
#             GDP  Annual_percent_growth  billions_of_us  percent_of_GDP  \
# 0  3.416650e+12                   7.24    4.560600e+11           13.35
# 1  3.150310e+12                   9.05    4.559100e+11           14.47
# 2  2.671600e+12                  -5.83    3.773500e+11           14.12
# 3  2.835610e+12                   3.87    3.815500e+11           13.46
# 4  2.702930e+12                   6.45    4.022400e+11           14.88
#
#    GDP_growth  Annual_Change  GDP_Per_Capita     GNI  GNI_Per_Capita  \
# 0        7.24          -1.81          2411.0  2390.0          2390.0
# 1        9.05          14.88          2238.0  2150.0          2150.0
# 2       -5.83          -9.70          1913.0  1900.0          1900.0
# 3        3.87          -2.58          2050.0  2080.0          2080.0
# 4        6.45          -0.34          1974.0  1980.0          1980.0
#
#             GNP  Inflation_Rate
# 0  3.385770e+12            6.70
# 1  3.019860e+12            5.13
# ...

# %%
df1.columns
# Out:
# Index(['GDP', 'Annual_percent_growth', 'billions_of_us', 'percent_of_GDP',
#        'GDP_growth', 'Annual_Change', 'GDP_Per_Capita', 'GNI',
#        'GNI_Per_Capita', 'GNP', 'Inflation_Rate'],
#       dtype='object')

# %%
df = df1[['Annual_percent_growth', 'billions_of_us', 'percent_of_GDP',
       'GDP_growth', 'Annual_Change', 'GDP_Per_Capita', 'GNI',
       'GNI_Per_Capita', 'GNP', 'Inflation_Rate']]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
#since few columns are highly correlating we will be droping few columns

# %%
df1.drop(['GNP','GNI_Per_Capita','GNI'], axis=1 , inplace=True)

# %%
df1.head()
# Out:
#             GDP  Annual_percent_growth  billions_of_us  percent_of_GDP  \
# 0  3.416650e+12                   7.24    4.560600e+11           13.35
# 1  3.150310e+12                   9.05    4.559100e+11           14.47
# 2  2.671600e+12                  -5.83    3.773500e+11           14.12
# 3  2.835610e+12                   3.87    3.815500e+11           13.46
# 4  2.702930e+12                   6.45    4.022400e+11           14.88
#
#    GDP_growth  Annual_Change  GDP_Per_Capita  Inflation_Rate
# 0        7.24          -1.81          2411.0            6.70
# 1        9.05          14.88          2238.0            5.13
# 2       -5.83          -9.70          1913.0            6.62
# 3        3.87          -2.58          2050.0            3.73
# 4        6.45          -0.34          1974.0            3.94

# %%
df1.drop(['Annual_percent_growth'],axis=1 , inplace=True)

# %%
df1.head()
# Out:
#             GDP  billions_of_us  percent_of_GDP  GDP_growth  Annual_Change  \
# 0  3.416650e+12    4.560600e+11           13.35        7.24          -1.81
# 1  3.150310e+12    4.559100e+11           14.47        9.05          14.88
# 2  2.671600e+12    3.773500e+11           14.12       -5.83          -9.70
# 3  2.835610e+12    3.815500e+11           13.46        3.87          -2.58
# 4  2.702930e+12    4.022400e+11           14.88        6.45          -0.34
#
#    GDP_Per_Capita  Inflation_Rate
# 0          2411.0            6.70
# 1          2238.0            5.13
# 2          1913.0            6.62
# 3          2050.0            3.73
# 4          1974.0            3.94

# %%
df2=df1[['GDP', 'billions_of_us', 'percent_of_GDP',
       'GDP_growth', 'Annual_Change', 'GDP_Per_Capita', 'Inflation_Rate']]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df2.corr(),annot=True)
plt.show()

# %%
df1.drop(['billions_of_us'],axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['GDP', 'percent_of_GDP', 'GDP_growth', 'Annual_Change',
#        'GDP_Per_Capita', 'Inflation_Rate'],
#       dtype='object')

# %%
df3=df1[['GDP', 'percent_of_GDP', 'GDP_growth', 'Annual_Change',
       'GDP_Per_Capita', 'Inflation_Rate']]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df3.corr(),annot=True)
plt.show()

# %% [markdown]
# # **MODEL PREPRATION**

# %%
df1.columns
# Out:
# Index(['GDP', 'percent_of_GDP', 'GDP_growth', 'Annual_Change',
#        'GDP_Per_Capita', 'Inflation_Rate'],
#       dtype='object')

# %%
x = df1[['percent_of_GDP', 'GDP_growth', 'Annual_Change',
       'GDP_Per_Capita', 'Inflation_Rate']]
y = df1['GDP']

# %%
from sklearn.model_selection import train_test_split

# %%
x
# Out:
#     percent_of_GDP  GDP_growth  Annual_Change  GDP_Per_Capita  Inflation_Rate
# 0            13.35        7.24          -1.81          2411.0            6.70
# 1            14.47        9.05          14.88          2238.0            5.13
# 2            14.12       -5.83          -9.70          1913.0            6.62
# 3            13.46        3.87          -2.58          2050.0            3.73
# 4            14.88        6.45          -0.34          1974.0            3.94
# ..             ...         ...            ...             ...             ...
# 58           14.85        7.45           1.46           115.0           13.36
# 59           15.75        5.99           3.06           101.0            2.95
# 60           15.86        2.93          -0.79            90.0            3.63
# 61           15.35        3.72           3.72            86.0            1.70
# 62           14.75        0.00           3.72            83.0            1.78
#
# [63 rows x 5 columns]

# %%
x.shape
# Out:
# (63, 5)

# %%
y
# Out:
# 0     3.416650e+12
# 1     3.150310e+12
# 2     2.671600e+12
# 3     2.835610e+12
# 4     2.702930e+12
#           ...
# 58    5.648000e+10
# 59    4.842000e+10
# 60    4.216000e+10
# 61    3.923000e+10
# 62    3.703000e+10
# Name: GDP, Length: 63, dtype: float64

# %%
y.shape
# Out:
# (63,)

# %% [markdown]
# # **SPliting data**

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#     percent_of_GDP  GDP_growth  Annual_Change  GDP_Per_Capita  Inflation_Rate
# 13           17.14        7.86           4.78          1097.0           10.88
# 34           16.10        9.63           5.66           356.0            9.38
# 49           15.02        3.30           3.85           143.0           16.94
# 3            13.46        3.87          -2.58          2050.0            3.73
# 17           15.97        7.92           0.00           711.0            4.25
# 48           16.35        1.19          -2.11           163.0           28.60
# 8            15.07        7.41           1.02          1560.0            6.67
# 6            15.16        8.26           0.26          1714.0            4.95
# 33           16.90        5.95          -3.68           347.0            7.07
# 4            14.88        6.45          -0.34          1974.0            3.94
# 46           16.27        1.66          -7.49           161.0           -7.63
# ...

# %%
x_test
# Out:
#     percent_of_GDP  GDP_growth  Annual_Change  GDP_Per_Capita  Inflation_Rate
# 61           15.35        3.72           3.72            86.0            1.70
# 57           15.01       -2.64         -10.09           119.0            9.47
# 0            13.35        7.24          -1.81          2411.0            6.70
# 43           17.85       -5.24         -10.95           225.0            6.28
# 5            15.02        6.80          -1.46          1958.0            3.33
# 36           16.22        4.78          -0.48           312.0            8.73
# 16           17.30        8.06           0.14           802.0            5.80
# 12           17.03        8.50           0.64          1351.0           11.99
# 25           16.52        4.05          -3.50           415.0            7.16
# 60           15.86        2.93          -0.79            90.0            3.63
# 55           13.23        7.83           7.88            96.0           13.06
# ...

# %%
y_train
# Out:
# 13    1.341890e+12
# 34    2.965900e+11
# 49    8.552000e+10
# 3     2.835610e+12
# 17    8.203800e+11
# 48    9.953000e+10
# 8     2.039130e+12
# 6     2.294800e+12
# 33    2.960400e+11
# 4     2.702930e+12
# 46    1.027200e+11
# 19    6.077000e+11
# 53    5.845000e+10
# 41    1.934900e+11
# 54    5.309000e+10
# 31    2.701100e+11
# 30    2.882100e+11
# 58    5.648000e+10
# 59    4.842000e+10
# 15    1.216740e+12
# 27    3.602800e+11
# 26    3.929000e+11
# 24    4.213500e+11
# 45    1.214900e+11
# 11    1.823050e+12
# 32    3.209800e+11
# 56    4.587000e+10
# 44    1.373000e+11
# 37    2.325100e+11
# 29    2.793000e+11
# 47    9.847000e+10
# 1     3.150310e+12
# 21    4.854400e+11
# 2     2.671600e+12
# 50    7.146000e+10
# 39    2.182600e+11
# 35    2.790300e+11
# 23    4.588200e+11
# 52    6.242000e+10
# 10    1.827640e+12
# 22    4.683900e+11
# 18    7.091500e+11
# 62    3.703000e+10
# 20    5.149400e+11
# 7     2.103590e+12
# 42    1.863300e+11
# 14    1.198900e+12
# ...

# %%
y_test
# Out:
# 61    3.923000e+10
# 57    5.955000e+10
# 0     3.416650e+12
# 43    1.529900e+11
# 5     2.651470e+12
# 36    2.489900e+11
# 16    9.402600e+11
# 12    1.675620e+12
# 25    4.158700e+11
# 60    4.216000e+10
# 55    5.013000e+10
# 9     1.856720e+12
# 40    2.007200e+11
# Name: GDP, dtype: float64

# %% [markdown]
# # **Model selection**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, r2_score

# %%
lr=LinearRegression(fit_intercept=True, copy_X=True, n_jobs=None, positive=False)
rg = Ridge(alpha=1.0,fit_intercept=True, copy_X=True, max_iter=None, tol=0.0001, solver='auto', positive=False, random_state=None)
ran = RANSACRegressor(estimator=None, min_samples=None, residual_threshold=None, is_data_valid=None, is_model_valid=None, max_trials=100, stop_probability=0.99, loss='absolute_error', random_state=None)
las = Lasso(alpha=1.0, fit_intercept=True, precompute=False, copy_X=True, max_iter=1000, tol=0.0001, warm_start=False, positive=False, random_state=None, selection='cyclic')
svr = SVR(kernel='rbf', degree=3, gamma='scale', coef0=0.0, tol=0.001, C=1.0, epsilon=0.1, shrinking=True, cache_size=200, verbose=False, max_iter=-1)
dt = DecisionTreeRegressor(criterion='squared_error', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, ccp_alpha=0.0, monotonic_cst=None)
rf = RandomForestRegressor(n_estimators=100, criterion='squared_error', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=1.0, max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, ccp_alpha=0.0, max_samples=None, monotonic_cst=None)
ab = AdaBoostRegressor(estimator=None, n_estimators=50, learning_rate=1.0, loss='linear', random_state=None)
br = BaggingRegressor(estimator=None, n_estimators=10, max_samples=1.0, max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, warm_start=False, n_jobs=None, random_state=None, verbose=0)
etr = ExtraTreesRegressor(n_estimators=100, criterion='squared_error', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=1.0, max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=False, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, ccp_alpha=0.0, max_samples=None, monotonic_cst=None)
gbr = GradientBoostingRegressor(loss='squared_error', learning_rate=0.1, n_estimators=100, subsample=1.0, criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0, init=None, random_state=None, max_features=None, alpha=0.9, verbose=0, max_leaf_nodes=None, warm_start=False, validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)
knr = KNeighborsRegressor(n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=None)
xgb = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)

# %%
reg = {
    'LR' : lr,
    'Ridge' : rg,
    'RAN' : ran,
    'Lasso' : las,
    'SVR' : svr,
    'DT' : dt,
    'RF' : rf,
    'Adaboost' : ab,
    'Bag' : br,
    'ETR':etr,
    'GBR':gbr,
    'KN':knr,
    'XGB':xgb

}

# %%
def train_reg(regressor,x_train,y_train,x_test,y_test):
    regressor.fit(x_train,y_train)
    y_pred = regressor.predict(x_test)
    mse = mean_absolute_error(y_test,y_pred)
    rmse = root_mean_squared_error(y_test,y_pred)
    mae = mean_absolute_error(y_test,y_pred)
    r2 = r2_score(y_test,y_pred)

    return mse,rmse,mae,r2

# %%
mse1=[]
rmse1=[]
mae1=[]
r2_1=[]

for name,regressor in reg.items():
    mse,rmse,mae,r2=train_reg(regressor,x_train,y_train,x_test,y_test)
    print("For",name)
    print("mean_squared_error - ",mse)
    print("root_mean_squared_error - ",rmse)
    print("mean_absolute_error - ",mae)
    print("r2_score - ",r2_score)

    mse1.append(mse)
    rmse1.append(rmse)
    mae1.append(mae)
    r2_1.append(r2)
# Out:
# For LR
# mean_squared_error -  27612351444.43299
# root_mean_squared_error -  36175117752.38192
# mean_absolute_error -  27612351444.43299
# r2_score -  <function r2_score at 0x000001BCC0F2B9C0>
# For Ridge
# mean_squared_error -  27348840634.073055
# root_mean_squared_error -  36364499975.628296
# mean_absolute_error -  27348840634.073055
# r2_score -  <function r2_score at 0x000001BCC0F2B9C0>
# For RAN
# mean_squared_error -  27612351444.43297
# root_mean_squared_error -  36175117752.38191
# mean_absolute_error -  27612351444.43297
# r2_score -  <function r2_score at 0x000001BCC0F2B9C0>
# For Lasso
# mean_squared_error -  27612351444.297512
# root_mean_squared_error -  36175117752.63229
# mean_absolute_error -  27612351444.297512
# r2_score -  <function r2_score at 0x000001BCC0F2B9C0>
# For SVR
# mean_squared_error -  804548846146.0684
# root_mean_squared_error -  1250502129608.4272
# mean_absolute_error -  804548846146.0684
# r2_score -  <function r2_score at 0x000001BCC0F2B9C0>
# ...

# %%
performance_df = pd.DataFrame({'Algorithm':reg.keys(),'mse':mse1,'rmse':rmse1,'mae':mae1,'r2':r2_1}).sort_values('r2',ascending=False)

# %%
performance_df
# Out:
#    Algorithm           mse          rmse           mae        r2
# 0         LR  2.761235e+10  3.617512e+10  2.761235e+10  0.998905
# 2        RAN  2.761235e+10  3.617512e+10  2.761235e+10  0.998905
# 3      Lasso  2.761235e+10  3.617512e+10  2.761235e+10  0.998905
# 1      Ridge  2.734884e+10  3.636450e+10  2.734884e+10  0.998893
# 9        ETR  5.138866e+10  1.154878e+11  5.138866e+10  0.988835
# 5         DT  7.794154e+10  1.349532e+11  7.794154e+10  0.984755
# 10       GBR  6.908697e+10  1.458619e+11  6.908697e+10  0.982191
# 11        KN  9.156477e+10  2.014431e+11  9.156477e+10  0.966032
# 6         RF  9.189545e+10  2.058650e+11  9.189545e+10  0.964524
# 12       XGB  1.496467e+11  2.077609e+11  1.496467e+11  0.963868
# 7   Adaboost  1.344984e+11  2.218408e+11  1.344984e+11  0.958804
# 8        Bag  1.187695e+11  2.378814e+11  1.187695e+11  0.952632
# 4        SVR  8.045488e+11  1.250502e+12  8.045488e+11 -0.308990

# %%
#Models like Linear regression, RANSAC,RIDGE,LASSO has extremely high r2 score hence overly fitting

# %%
#gradient boost regressor and extra tree regressor are the most suitable ones

# %%
performance_df1 = pd.melt(performance_df, id_vars='Algorithm')

# %%
performance_df1
# Out:
#    Algorithm variable         value
# 0         LR      mse  2.761235e+10
# 1        RAN      mse  2.761235e+10
# 2      Lasso      mse  2.761235e+10
# 3      Ridge      mse  2.734884e+10
# 4        ETR      mse  5.138866e+10
# 5         DT      mse  7.794154e+10
# 6        GBR      mse  6.908697e+10
# 7         KN      mse  9.156477e+10
# 8         RF      mse  9.189545e+10
# 9        XGB      mse  1.496467e+11
# 10  Adaboost      mse  1.344984e+11
# 11       Bag      mse  1.187695e+11
# 12       SVR      mse  8.045488e+11
# 13        LR     rmse  3.617512e+10
# 14       RAN     rmse  3.617512e+10
# 15     Lasso     rmse  3.617512e+10
# 16     Ridge     rmse  3.636450e+10
# 17       ETR     rmse  1.154878e+11
# 18        DT     rmse  1.349532e+11
# 19       GBR     rmse  1.458619e+11
# 20        KN     rmse  2.014431e+11
# 21        RF     rmse  2.058650e+11
# 22       XGB     rmse  2.077609e+11
# 23  Adaboost     rmse  2.218408e+11
# 24       Bag     rmse  2.378814e+11
# ...

# %%
plt.figure(figsize=(15,10))
sns.catplot(x='Algorithm', y='value', hue='variable',data=performance_df1, kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
# so our best model are gradient boosting regressor and extra trees regressor

# %%
gbr.fit(x_train,y_train)
y_pred2 = gbr.predict(x_test)
print(mean_absolute_error(y_test,y_pred2))
print(mean_squared_error(y_test,y_pred2))
print(root_mean_squared_error(y_test,y_pred2))
print(r2_score(y_test,y_pred2))
# Out:
# 55857396541.584435
# 1.5892999274878885e+22
# 126067439392.09238
# 0.9866962756541513

# %%
y_pred2
# Out:
# array([3.79231175e+10, 6.85469478e+10, 2.97869054e+12, 1.36933567e+11,
#        2.57058095e+12, 2.84976070e+11, 8.71289090e+11, 1.69817361e+12,
#        4.18703592e+11, 4.58860228e+10, 5.03746444e+10, 1.89115662e+12,
#        2.12905909e+11])

# %%
plt.figure(figsize=(10,6))#best fit line for train data
plt.scatter(y_test, y_pred2)
plt.show()

# %%
#since we have a very small dataset the resulting output is not a lot

# %%
#still the results has a linear pattern in it which is a positive outcome of our analysis

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test, y_pred2, color='m', label='Actual Price')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4, label='Predicted Price')
plt.title('Best fit line on Training Data')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
# Out:
# Text(0, 0.5, 'Predicted Price')

# %%
''' we have less data since india is just a 77yr old 
our dataset has data till 2022, from which we have taken data of 63 years'''
# Out:
# ' we have less data since india is just a 77yr old \nour dataset has data till 2022, from which we have taken data of 63 years'

# %% [markdown]
# # **END OF CODE**
